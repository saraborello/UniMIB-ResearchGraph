# %%
p1_index = df[(df['Given Name'] == 'FRANCESCA') & (df['Family Name'] == 'ARCELLI FONTANA')].index
if not p1_index.empty:
    
    df.loc[p1_index, 'Keywords'] = "Software Engineering, Refactoring, Managing Technical Debt, Architectural Smell Detection, Software Quality Assessment"
    df.loc[p1_index, 'H Index'] = 5789
    df.loc[p1_index, 'Citations'] = 40
else:
    print("NOT FOUND")

p2_index = df[(df['Given Name'] == 'STEFANIA') & (df['Family Name'] == 'BANDINI')].index
if not p2_index.empty:
    
    df.loc[p2_index, 'Keywords'] = "artificial intelligence, complex systems, crowd-pedestrians modeling and simulation"
    df.loc[p2_index, 'H Index'] = 4738
    df.loc[p2_index, 'Citations'] = 35
else:
    print("NOT FOUND")

p3_index = df[(df['Given Name'] == 'OLIVIERO') & (df['Family Name'] == 'RIGANELLI')].index
if not p3_index.empty:
    
    df.loc[p3_index, 'Keywords'] = "Software Testing, Software Analysis, Software Engineering"
    df.loc[p3_index, 'H Index'] = 856
    df.loc[p3_index, 'Citations'] = 15
else:
    print("NOT FOUND")

p4_index = df[(df['Given Name'] == 'FABIO') & (df['Family Name'] == 'SARTORI')].index
if not p4_index.empty:
    
    df.loc[p4_index, 'Keywords'] = "Artificial Intelligence"
    df.loc[p4_index, 'H Index'] = 660
    df.loc[p4_index, 'Citations'] = 14
else:
    print("NOT FOUND")

p5_index = df[(df['Given Name'] == 'LUIGI') & (df['Family Name'] == 'CELONA')].index
if not p5_index.empty:
    
    df.loc[p5_index, 'Keywords'] = "Visual quality assessment, Computer vision, Deep learning, Machine learning"
    df.loc[p5_index, 'H Index'] = 2033
    df.loc[p5_index, 'Citations'] = 16
else:
    print("NOT FOUND")

p6_index = df[(df['Given Name'] == 'MARCO') & (df['Family Name'] == 'CREMASCHI')].index
if not p6_index.empty:
    
    df.loc[p6_index, 'Keywords'] = "Semantic Web, Table interpretation, Semantic Annotations, Clinical Decision Support System"
    df.loc[p6_index, 'H Index'] = 342
    df.loc[p6_index, 'Citations'] = 11
else:
    print("NOT FOUND")

# %%
p7_index = df[(df['Given Name'] == 'GEORGIOS') & (df['Family Name'] == 'PEIKOS')].index
if not p7_index.empty:
    
    df.loc[p7_index, 'Keywords'] = "Information Retrieval, Natural Language Processing, Health Informatics"
    df.loc[p7_index, 'H Index'] = 62
    df.loc[p7_index, 'Citations'] = 5
else:
    print("NOT FOUND")



p8_index = df[(df['Given Name'] == 'FEDERICO') & (df['Family Name'] == 'BELOTTI')].index
if not p8_index.empty:
    
    df.loc[p8_index, 'Keywords'] = "NLP, Semantic Table Interpretation, Interpretability"
    df.loc[p8_index, 'H Index'] = 18
    df.loc[p8_index, 'Citations'] = 2
else:
    print("NOT FOUND")

p9_index = df[(df['Given Name'] == 'STEFANIA') & (df['Family Name'] == 'BOFFA')].index
if not p9_index.empty:
    
    df.loc[p9_index, 'Keywords'] = ""
    df.loc[p9_index, 'H Index'] = 141
    df.loc[p9_index, 'Citations'] = 7
else:
    print("NOT FOUND")

p10_index = df[(df['Given Name'] == 'XIAOCHEN') & (df['Family Name'] == 'CHOU')].index
if not p10_index.empty:
    
    df.loc[p10_index, 'Keywords'] = "Operations Research, Machine Learning"
    df.loc[p10_index, 'H Index'] = 163
    df.loc[p10_index, 'Citations'] = 7
else:
    print("NOT FOUND")

p11_index = df[(df['Given Name'] == 'FEDERICA') & (df['Family Name'] == 'FILIPPINI')].index
if not p11_index.empty:
    
    df.loc[p11_index, 'Keywords'] = ""
    df.loc[p11_index, 'H Index'] = 49
    df.loc[p11_index, 'Citations'] = 6
else:
    print("NOT FOUND")

p12_index = df[(df['Given Name'] == 'ALESSANDRA') & (df['Family Name'] == 'GROSSI')].index
if not p12_index.empty:
    
    df.loc[p12_index, 'Keywords'] = "Effective computing, signal analysis, physiological signal, speech emotion recognition"
    df.loc[p12_index, 'H Index'] = 49
    df.loc[p12_index, 'Citations'] = 5
else:
    print("NOT FOUND")
